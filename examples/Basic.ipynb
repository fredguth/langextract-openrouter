# %%
import os
import langextract as lx
import textwrap

# %%
prompt = textwrap.dedent("""\
    Extract characters, emotions, and relationships in order of appearance.
    Use exact text for extractions. Do not paraphrase or overlap entities.
    Provide meaningful attributes for each entity to add context.""")

# %%
# Provide high-quality examples to guide the model
examples = [
    lx.data.ExampleData(
        text="ROMEO. But soft! What light through yonder window breaks? It is the east, and Juliet is the sun.",
        extractions=[
            lx.data.Extraction(
                extraction_class="character",
                extraction_text="ROMEO",
                attributes={"emotional_state": "wonder"}
            ),
            lx.data.Extraction(
                extraction_class="emotion",
                extraction_text="But soft!",
                attributes={"feeling": "gentle awe"}
            ),
            lx.data.Extraction(
                extraction_class="relationship",
                extraction_text="Juliet is the sun",
                attributes={"type": "metaphor"}
            ),
        ]
    )
]

# %%
# Create model configuration
config = lx.factory.ModelConfig(
    model_id="openrouter/deepseek/deepseek-chat-v3.1",
    provider="OpenrouterLanguageModel",
)
model = lx.factory.create_model(config)

# %%
result = lx.extract(
    text_or_documents="Lady Juliet gazed longingly at the stars, her heart aching for Romeo",
    model=model,
    prompt_description=prompt,
    examples=examples
)

print("✅ Extraction successful!")
print(f"Results: {result}")
# Out:
# /var/folders/gm/fbvqv1z96zzb73768sgn_jp80000gn/T/ipykernel_66183/3380449791.py:1: UserWarning: 'use_schema_constraints' is ignored when 'model' is provided. The model should already be configured with schema constraints.
#   result = lx.extract(
# DEBUG:absl:Initialized Annotator with prompt:
# Extract characters, emotions, and relationships in order of appearance.
# Use exact text for extractions. Do not paraphrase or overlap entities.
# Provide meaningful attributes for each entity to add context.
#
# Examples
# Q: ROMEO. But soft! What light through yonder window breaks? It is the east, and Juliet is the sun.
# A: ```json
# {
#   "extractions": [
#     {
#       "character": "ROMEO",
#       "character_attributes": {
#         "emotional_state": "wonder"
#       }
#     },
#     {
#       "emotion": "But soft!",
#       "emotion_attributes": {
#         "feeling": "gentle awe"
#       }
#     },
#     {
#       "relationship": "Juliet is the sun",
#       "relationship_attributes": {
#         "type": "metaphor"
#       }
#     }
#   ]
# }
# ```
#
# Q:
# A:
# INFO:absl:Starting document annotation.
# LangExtract: model=deepseek/deepseek-chat-v3.1 [00:00]2025-08-25 23:38:32,384 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-25 23:38:32,385 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.3 ms)
# INFO:absl:Processing batch 0 with length 1
# DEBUG:absl:Token util returns string: Lady Juliet gazed longingly at the stars, her heart aching for Romeo for tokenized_text: TokenizedText(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo', tokens=[Token(index=0, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=0, end_pos=4), first_token_after_newline=False), Token(index=1, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=5, end_pos=11), first_token_after_newline=False), Token(index=2, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=12, end_pos=17), first_token_after_newline=False), Token(index=3, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=18, end_pos=27), first_token_after_newline=False), Token(index=4, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=28, end_pos=30), first_token_after_newline=False), Token(index=5, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=31, end_pos=34), first_token_after_newline=False), Token(index=6, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=35, end_pos=40), first_token_after_newline=False), Token(index=7, token_type=<TokenType.PUNCTUATION: 2>, char_interval=CharInterval(start_pos=40, end_pos=41), first_token_after_newline=False), Token(index=8, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=42, end_pos=45), first_token_after_newline=False), Token(index=9, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=46, end_pos=51), first_token_after_newline=False), Token(index=10, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=52, end_pos=58), first_token_after_newline=False), Token(index=11, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=59, end_pos=62), first_token_after_newline=False), Token(index=12, token_type=<TokenType.WORD: 0>, char_interval=CharInterval(start_pos=63, end_pos=68), first_token_after_newline=False)]), token_interval: TokenInterval(start_index=0, end_index=13)
# LangExtract: model=deepseek/deepseek-chat-v3.1, current=68 chars, processed=68 chars:  [00:00]DEBUG:absl:Processing chunk: TextChunk(
#   interval=[start_index: 0, end_index: 13],
#   Document ID: doc_cfa8da04,
#   Chunk Text: 'Lady Juliet gazed longingly at the stars, her heart aching for Romeo'
# )
# DEBUG:absl:Top inference result: ```json
# {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "action": "gazed at the stars"
#       }
#     },
#     {
#       "emotion": "longingly",
#       "emotion_attributes": {
#         "feeling": "yearning"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sad desire"
#       }
#     },
#     {
#       "relationship": "Romeo",
#       "relationship_attributes": {
#         "type": "object of desire"
#       }
#     }
#   ]
# }
# ```
# INFO:absl:Starting resolver process for input text.
# DEBUG:absl:Input Text: ```json
# {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "action": "gazed at the stars"
#       }
#     },
#     {
#       "emotion": "longingly",
#       "emotion_attributes": {
#         "feeling": "yearning"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sad desire"
#       }
#     },
#     {
#       "relationship": "Romeo",
#       "relationship_attributes": {
#         "type": "object of desire"
#       }
#     }
#   ]
# }
# ```
# INFO:absl:Starting string parsing.
# DEBUG:absl:input_string: ```json
# {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "action": "gazed at the stars"
#       }
#     },
#     {
#       "emotion": "longingly",
#       "emotion_attributes": {
#         "feeling": "yearning"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sad desire"
#       }
#     },
#     {
#       "relationship": "Romeo",
#       "relationship_attributes": {
#         "type": "object of desire"
#       }
#     }
#   ]
# }
# ```
# DEBUG:absl:Content: {
#   "extractions": [
#     {
#       "character": "Lady Juliet",
#       "character_attributes": {
#         "action": "gazed at the stars"
#       }
#     },
#     {
#       "emotion": "longingly",
#       "emotion_attributes": {
#         "feeling": "yearning"
#       }
#     },
#     {
#       "emotion": "her heart aching",
#       "emotion_attributes": {
#         "feeling": "sad desire"
#       }
#     },
#     {
#       "relationship": "Romeo",
#       "relationship_attributes": {
#         "type": "object of desire"
#       }
#     }
#   ]
# }
# DEBUG:absl:Successfully parsed content.
# INFO:absl:Completed parsing of string.
# DEBUG:absl:Parsed content: [{'character': 'Lady Juliet', 'character_attributes': {'action': 'gazed at the stars'}}, {'emotion': 'longingly', 'emotion_attributes': {'feeling': 'yearning'}}, {'emotion': 'her heart aching', 'emotion_attributes': {'feeling': 'sad desire'}}, {'relationship': 'Romeo', 'relationship_attributes': {'type': 'object of desire'}}]
# INFO:absl:Starting to extract and order extractions from data.
# INFO:absl:Completed extraction and ordering of extractions.
# DEBUG:absl:Completed the resolver process.
# INFO:absl:Starting alignment process for provided chunk text.
# DEBUG:absl:WordAligner: Starting alignment of extractions with the source text. Extraction groups to align: [[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=None, alignment_status=None, extraction_index=1, group_index=0, description=None, attributes={'action': 'gazed at the stars'}), Extraction(extraction_class='emotion', extraction_text='longingly', char_interval=None, alignment_status=None, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'yearning'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=None, alignment_status=None, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sad desire'}), Extraction(extraction_class='relationship', extraction_text='Romeo', char_interval=None, alignment_status=None, extraction_index=4, group_index=3, description=None, attributes={'type': 'object of desire'})]]
# 2025-08-25 23:38:37,502 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-25 23:38:37,503 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-25 23:38:37,504 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='␟')
# 2025-08-25 23:38:37,504 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Using delimiter '␟' for extraction alignment
# 2025-08-25 23:38:37,506 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet ␟ longingly ␟ her heart aching ␟ Romeo')
# 2025-08-25 23:38:37,507 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# DEBUG:absl:Processing extraction group 0 with 4 extractions.
# 2025-08-25 23:38:37,508 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet')
# 2025-08-25 23:38:37,509 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,509 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='longingly')
# 2025-08-25 23:38:37,510 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,511 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='her heart aching')
# 2025-08-25 23:38:37,511 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,512 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Romeo')
# 2025-08-25 23:38:37,512 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,513 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
# 2025-08-25 23:38:37,513 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.1 ms)
# 2025-08-25 23:38:37,514 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Lady Juliet')
# 2025-08-25 23:38:37,514 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,515 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='longingly')
# 2025-08-25 23:38:37,515 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,516 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='her heart aching')
# 2025-08-25 23:38:37,516 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# 2025-08-25 23:38:37,517 - langextract.debug - DEBUG - [langextract.tokenizer] CALL: tokenize(text='Romeo')
# 2025-08-25 23:38:37,517 - langextract.debug - DEBUG - [langextract.tokenizer] RETURN: tokenize -> TokenizedText...wline=False)]) (0.0 ms)
# DEBUG:absl:Final aligned extraction groups: [[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'action': 'gazed at the stars'}), Extraction(extraction_class='emotion', extraction_text='longingly', char_interval=CharInterval(start_pos=18, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'yearning'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sad desire'}), Extraction(extraction_class='relationship', extraction_text='Romeo', char_interval=CharInterval(start_pos=63, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'object of desire'})]]
# DEBUG:absl:Aligned extractions count: 4
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'action': 'gazed at the stars'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='emotion', extraction_text='longingly', char_interval=CharInterval(start_pos=18, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'yearning'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sad desire'})
# DEBUG:absl:Yielding aligned extraction: Extraction(extraction_class='relationship', extraction_text='Romeo', char_interval=CharInterval(start_pos=63, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'object of desire'})
# INFO:absl:Completed alignment process for the provided source_text.
# LangExtract: model=deepseek/deepseek-chat-v3.1, current=68 chars, processed=68 chars:  [00:05]
# ✓ Extraction processing complete
# INFO:absl:Finalizing annotation for document ID doc_cfa8da04.
# INFO:absl:Document annotation completed.
# ✓ Extracted 4 entities (3 unique types)
#   • Time: 5.16s
#   • Speed: 13 chars/sec
#   • Chunks: 1
# ✅ Extraction successful!
# Results: AnnotatedDocument(extractions=[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'action': 'gazed at the stars'}), Extraction(extraction_class='emotion', extraction_text='longingly', char_interval=CharInterval(start_pos=18, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'yearning'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sad desire'}), Extraction(extraction_class='relationship', extraction_text='Romeo', char_interval=CharInterval(start_pos=63, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'object of desire'})], text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')

# %%
result
# Out:
# AnnotatedDocument(extractions=[Extraction(extraction_class='character', extraction_text='Lady Juliet', char_interval=CharInterval(start_pos=0, end_pos=11), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=1, group_index=0, description=None, attributes={'action': 'gazed at the stars'}), Extraction(extraction_class='emotion', extraction_text='longingly', char_interval=CharInterval(start_pos=18, end_pos=27), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=2, group_index=1, description=None, attributes={'feeling': 'yearning'}), Extraction(extraction_class='emotion', extraction_text='her heart aching', char_interval=CharInterval(start_pos=42, end_pos=58), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=3, group_index=2, description=None, attributes={'feeling': 'sad desire'}), Extraction(extraction_class='relationship', extraction_text='Romeo', char_interval=CharInterval(start_pos=63, end_pos=68), alignment_status=<AlignmentStatus.MATCH_EXACT: 'match_exact'>, extraction_index=4, group_index=3, description=None, attributes={'type': 'object of desire'})], text='Lady Juliet gazed longingly at the stars, her heart aching for Romeo')
